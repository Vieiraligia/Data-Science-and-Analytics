-- %%
---CAMADA BRONZE

-- %%
CREATE CATALOG IF NOT EXISTS bronze_cyber_breaches;
USE CATALOG bronze_cyber_breaches;
CREATE SCHEMA IF NOT EXISTS bronze_cyber_breaches;
USE SCHEMA bronze_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE CATALOG IF NOT EXISTS main;

CREATE SCHEMA IF NOT EXISTS main.bronze;
CREATE SCHEMA IF NOT EXISTS main.silver;
CREATE SCHEMA IF NOT EXISTS main.gold;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
USE CATALOG main;
USE SCHEMA bronze;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE VOLUME IF NOT EXISTS main.bronze.raw_data;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
USE CATALOG main;
USE SCHEMA bronze;

CREATE OR REPLACE TABLE bronze_cyber_breaches
AS SELECT * 
FROM csv.`/Volumes/main/bronze/raw_data/bronze_cyber_breaches.csv`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM bronze_cyber_breaches LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th></tr></thead><tbody><tr><td>null</td><td>Entity</td><td>Year</td><td>Records</td><td>Organization type</td><td>Method</td><td>Sources</td></tr><tr><td>0</td><td>21st Century Oncology</td><td>2016</td><td>2200000</td><td>healthcare</td><td>hacked</td><td>[5][6]</td></tr><tr><td>1</td><td>500px</td><td>2020</td><td>14870304</td><td>social networking</td><td>hacked</td><td>[7]</td></tr><tr><td>2</td><td>Accendo Insurance Co.</td><td>2020</td><td>175350</td><td>healthcare</td><td>poor security</td><td>[8][9]</td></tr><tr><td>3</td><td>Adobe Systems Incorporated</td><td>2013</td><td>152000000</td><td>tech</td><td>hacked</td><td>[10]</td></tr><tr><td>4</td><td>Adobe Inc.</td><td>2019</td><td>7500000</td><td>tech</td><td>poor security</td><td>[11][12]</td></tr><tr><td>5</td><td>Advocate Medical Group</td><td>2017</td><td>4000000</td><td>healthcare</td><td>lost / stolen media</td><td>[13][14]</td></tr><tr><td>6</td><td>AerServ (subsidiary of InMobi)</td><td>2018</td><td>75000</td><td>advertising</td><td>hacked</td><td>[15]</td></tr><tr><td>7</td><td>Affinity Health Plan, Inc.</td><td>2013</td><td>344579</td><td>healthcare</td><td>lost / stolen media</td><td>[16][17]</td></tr><tr><td>8</td><td>Airtel</td><td>2019</td><td>320000000</td><td>telecommunications</td><td>poor security</td><td>[18]</td></tr><tr><td>9</td><td>Air Canada</td><td>2018</td><td>20000</td><td>transport</td><td>hacked</td><td>[19]</td></tr><tr><td>10</td><td>Amazon Japan G.K.</td><td>2019</td><td>unknown</td><td>web</td><td>accidentally published</td><td>[20][21]</td></tr><tr><td>11</td><td>TD Ameritrade</td><td>2005</td><td>200000</td><td>financial</td><td>lost / stolen media</td><td>[22]</td></tr><tr><td>12</td><td>Ancestry.com</td><td>2021</td><td>300000</td><td>web</td><td>poor security</td><td>[23]</td></tr><tr><td>13</td><td>Animal Jam</td><td>2020</td><td>46000000</td><td>gaming</td><td>hacked</td><td>[24]</td></tr><tr><td>14</td><td>Ankle & Foot Center of Tampa Bay, Inc.</td><td>2021</td><td>156000</td><td>healthcare</td><td>hacked</td><td>[25]</td></tr><tr><td>15</td><td>Anthem Inc.</td><td>2015</td><td>80000000</td><td>healthcare</td><td>hacked</td><td>[26][27]</td></tr><tr><td>16</td><td>AOL</td><td>2004</td><td>92000000</td><td>web</td><td>inside job, hacked</td><td>[28][29]</td></tr><tr><td>17</td><td>AOL</td><td>2006</td><td>20000000</td><td>web</td><td>accidentally published</td><td>[30]</td></tr><tr><td>18</td><td>AOL</td><td>2014</td><td>2400000</td><td>web</td><td>hacked</td><td>[31]</td></tr></tbody></table></div>

-- %%
---CAMADA SILVER

-- %%
USE CATALOG main;
USE SCHEMA bronze;

DESCRIBE TABLE bronze_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>_c0</td><td>string</td><td>null</td></tr><tr><td>_c1</td><td>string</td><td>null</td></tr><tr><td>_c2</td><td>string</td><td>null</td></tr><tr><td>_c3</td><td>string</td><td>null</td></tr><tr><td>_c4</td><td>string</td><td>null</td></tr><tr><td>_c5</td><td>string</td><td>null</td></tr><tr><td>_c6</td><td>string</td><td>null</td></tr></tbody></table></div>

-- %%
USE CATALOG main;
USE SCHEMA silver;

--- Ajustando os nomes das colunas

DROP TABLE IF EXISTS silver_cyber_breaches;

CREATE TABLE silver_cyber_breaches AS
SELECT
    -- ID
    TRY_CAST(_c0 AS INT) AS breach_id,

    -- Organização
    TRIM(_c1) AS organization,

    -- Ano 
    TRY_CAST(_c2 AS INT) AS year,

    -- Records Exposed 
    TRY_CAST(
        REGEXP_REPLACE(_c3, '[^0-9]', '') 
        AS BIGINT
    ) AS records_exposed,

    -- Tipo de organização (texto)
    INITCAP(TRIM(_c4)) AS organization_type,

    -- Método de violação
    INITCAP(TRIM(_c5)) AS breach_method,

    -- Metadados
    current_timestamp() AS silver_load_timestamp

FROM main.bronze.bronze_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM silver_cyber_breaches LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>breach_id</th><th>organization</th><th>year</th><th>records_exposed</th><th>organization_type</th><th>breach_method</th><th>silver_load_timestamp</th></tr></thead><tbody><tr><td>null</td><td>Entity</td><td>null</td><td>null</td><td>Organization Type</td><td>Method</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>0</td><td>21st Century Oncology</td><td>2016</td><td>2200000</td><td>Healthcare</td><td>Hacked</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>1</td><td>500px</td><td>2020</td><td>14870304</td><td>Social Networking</td><td>Hacked</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>2</td><td>Accendo Insurance Co.</td><td>2020</td><td>175350</td><td>Healthcare</td><td>Poor Security</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>3</td><td>Adobe Systems Incorporated</td><td>2013</td><td>152000000</td><td>Tech</td><td>Hacked</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>4</td><td>Adobe Inc.</td><td>2019</td><td>7500000</td><td>Tech</td><td>Poor Security</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>5</td><td>Advoc

-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>breach_id</td><td>int</td><td>null</td></tr><tr><td>organization</td><td>string</td><td>null</td></tr><tr><td>year</td><td>int</td><td>null</td></tr><tr><td>records_exposed</td><td>bigint</td><td>null</td></tr><tr><td>organization_type</td><td>string</td><td>null</td></tr><tr><td>breach_method</td><td>string</td><td>null</td></tr><tr><td>silver_load_timestamp</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

-- %%
SELECT MAX(TRY_CAST(records_exposed AS BIGINT)) 
FROM main.silver.silver_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max(TRY_CAST(records_exposed AS BIGINT))</th></tr></thead><tbody><tr><td>90000002208</td></tr></tbody></table></div>

-- %%
---- CAMADA GOLD

-- %%
USE CATALOG main;
USE SCHEMA gold;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
---Criando a tabela Dimensão de Organização

DROP TABLE IF EXISTS dim_organization;

CREATE TABLE dim_organization AS
SELECT 
    ROW_NUMBER() OVER (ORDER BY organization) AS organization_key,
    organization
FROM (
    SELECT DISTINCT organization
    FROM main.silver.silver_cyber_breaches
    WHERE organization IS NOT NULL
) sub;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
---Criando a tabela Dimensão de Tipo de Organização

DROP TABLE IF EXISTS dim_organization_type;

CREATE TABLE dim_organization_type AS
SELECT
  ROW_NUMBER() OVER (ORDER BY organization_type) AS organization_type_key,
  organization_type
FROM (
  SELECT DISTINCT organization_type
  FROM main.silver.silver_cyber_breaches
  WHERE organization_type IS NOT NULL
) t;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
---Criando a tabela Dimensão de Tipo de Ataque

DROP TABLE IF EXISTS dim_breach_method;

CREATE TABLE dim_breach_method AS
SELECT
  ROW_NUMBER() OVER (ORDER BY breach_method) AS breach_method_key,
  breach_method
FROM (
  SELECT DISTINCT breach_method
  FROM main.silver.silver_cyber_breaches
  WHERE breach_method IS NOT NULL
) t;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
---Criando a tabela Dimensão Ano

CREATE OR REPLACE TABLE main.gold.dim_year AS
SELECT
    ROW_NUMBER() OVER (ORDER BY year) AS year_key,
    year
FROM (
    SELECT DISTINCT year
    FROM main.silver.silver_cyber_breaches
    WHERE year IS NOT NULL
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
---Criando a Tabela Fato: Cyber Breaches referenciando todas as dimensões

CREATE OR REPLACE TABLE main.gold.fact_cyber_breaches AS
SELECT
    s.breach_id,
    o.organization_key,
    ot.organization_type_key,
    bm.breach_method_key,
    y.year_key,
    s.records_exposed,
    s.silver_load_timestamp AS fact_load_timestamp
FROM main.silver.silver_cyber_breaches s

LEFT JOIN main.gold.dim_organization o
    ON s.organization = o.organization

LEFT JOIN main.gold.dim_organization_type ot
    ON s.organization_type = ot.organization_type

LEFT JOIN main.gold.dim_breach_method bm
    ON s.breach_method = bm.breach_method

LEFT JOIN main.gold.dim_year y
    ON s.year = y.year;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SHOW TABLES IN main.gold;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>gold</td><td>dim_breach_method</td><td>false</td></tr><tr><td>gold</td><td>dim_organization</td><td>false</td></tr><tr><td>gold</td><td>dim_organization_type</td><td>false</td></tr><tr><td>gold</td><td>dim_year</td><td>false</td></tr><tr><td>gold</td><td>fact_cyber_breaches</td><td>false</td></tr></tbody></table></div>

-- %%
----- Consultas nas dimensões

SELECT COUNT(*) AS total_dim_organization
FROM main.gold.dim_organization;

SELECT COUNT(*) AS total_dim_organization_type
FROM main.gold.dim_organization_type;

SELECT COUNT(*) AS total_dim_breach_method
FROM main.gold.dim_breach_method;

SELECT COUNT(*) AS total_dim_year
FROM main.gold.dim_year;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_dim_organization</th></tr></thead><tbody><tr><td>331</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_dim_organization_type</th></tr></thead><tbody><tr><td>70</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_dim_breach_method</th></tr></thead><tbody><tr><td>24</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_dim_year</th></tr></thead><tbody><tr><td>19</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) AS total_dim_breach_method
FROM main.gold.dim_breach_method;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_dim_breach_method</th></tr></thead><tbody><tr><td>24</td></tr></tbody></table></div>

-- %%
----- Consulta na tabela fato


SELECT COUNT(*) AS total_fact
FROM main.gold.fact_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_fact</th></tr></thead><tbody><tr><td>352</td></tr></tbody></table></div>

-- %%
----- Comparativo entre tabelas (Silver e Gold)

SELECT 
    SUM(records_exposed) AS total_records_exposed
FROM main.gold.fact_cyber_breaches;

SELECT 
    SUM(records_exposed)
FROM main.silver.silver_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_records_exposed</th></tr></thead><tbody><tr><td>103363335836</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(records_exposed)</th></tr></thead><tbody><tr><td>103363335836</td></tr></tbody></table></div>

-- %%
---Ver uma amostra dos dados

SELECT *
FROM main.gold.fact_cyber_breaches
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>breach_id</th><th>organization_key</th><th>organization_type_key</th><th>breach_method_key</th><th>year_key</th><th>records_exposed</th><th>fact_load_timestamp</th></tr></thead><tbody><tr><td>0</td><td>3</td><td>26</td><td>5</td><td>13</td><td>2200000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>1</td><td>5</td><td>53</td><td>5</td><td>17</td><td>14870304</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>2</td><td>8</td><td>26</td><td>14</td><td>17</td><td>175350</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>3</td><td>10</td><td>56</td><td>5</td><td>10</td><td>152000000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>4</td><td>9</td><td>56</td><td>14</td><td>16</td><td>7500000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>5</td><td>11</td><td>26</td><td>12</td><td>14</td><td>4000000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>6</td><td>12</td><td>2</td><td>5</td><td>15</td><td>75000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>7</td><td>13</td><td>26</td><td>12</td><td>10</td><td>344579</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>8</td><td>15</td><td>60</td><td>14</td><td>16</td><td>320000000</td><td>2025-12-17T23:56:29.072Z</td></tr><tr><td>9</td><td>14</td><td>64</td><td>5</td><td>15</td><td>20000</td><td>2025-12-17T23:56:29.072Z</td></tr></tbody></table></div>

-- %%
----Teste de integridade (PK e FK)

SELECT COUNT(*) AS fk_organization_null
FROM main.gold.fact_cyber_breaches
WHERE organization_key IS NULL;

SELECT COUNT(*) AS fk_org_type_null
FROM main.gold.fact_cyber_breaches
WHERE organization_type_key IS NULL;

SELECT COUNT(*) AS fk_method_null
FROM main.gold.fact_cyber_breaches
WHERE breach_method_key IS NULL;

SELECT COUNT(*) AS fk_year_null
FROM main.gold.fact_cyber_breaches
WHERE year_key IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fk_organization_null</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fk_org_type_null</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fk_method_null</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fk_year_null</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

-- %%
SELECT organization_key, COUNT(*)
FROM main.gold.dim_organization
GROUP BY organization_key
HAVING COUNT(*) > 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>organization_key</th><th>count(1)</th></tr></thead><tbody></tbody></table></div>

-- %%
---- Como retornou '3' na dim_year e dim_breach_method foi aplicado a correção 
---- Criar registro “Desconhecido” na dimensão 

---  Inserir linha técnica na dim_year
INSERT INTO main.gold.dim_year (year_key, year)
VALUES (-1, -1);

--- Atualizar a fato para apontar para esse registro
UPDATE main.gold.fact_cyber_breaches
SET year_key = -1
WHERE year_key IS NULL;

--- Aplicar constraint
ALTER TABLE main.gold.fact_cyber_breaches
ADD CONSTRAINT chk_year_key_not_null
CHECK (year_key IS NOT NULL);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
---- Como retornou '1' na dim_year e dim_breach_method foi aplicado a correção 
---- Criar registro “Desconhecido” na dimensão 

---  Inserir linha técnica na dim_breach_method
INSERT INTO main.gold.dim_breach_method (breach_method_key, breach_method)
VALUES (-1, 'Unknown');

--- Atualizar a tabela fato
UPDATE main.gold.fact_cyber_breaches
SET breach_method_key = -1
WHERE breach_method_key IS NULL;

--- Aplicar constraint
ALTER TABLE main.gold.fact_cyber_breaches
ADD CONSTRAINT chk_breach_method_key_not_null
CHECK (breach_method_key IS NOT NULL);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
--- Consultas ---

---- Total de registros comprometidos por ano
SELECT 
    y.year,
    SUM(f.records_exposed) AS total_records
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y
    ON f.year_key = y.year_key
GROUP BY y.year
ORDER BY y.year;

---- Total de registros comprometidos método de ataque
SELECT 
    m.breach_method,
    SUM(f.records_exposed) AS total_records
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_breach_method m
    ON f.breach_method_key = m.breach_method_key
GROUP BY m.breach_method
ORDER BY total_records DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>total_records</th></tr></thead><tbody><tr><td>-1</td><td>90002365208</td></tr><tr><td>2004</td><td>92510000</td></tr><tr><td>2005</td><td>46825000</td></tr><tr><td>2006</td><td>71260000</td></tr><tr><td>2007</td><td>153286405</td></tr><tr><td>2008</td><td>69066500</td></tr><tr><td>2009</td><td>255467987</td></tr><tr><td>2010</td><td>15980476</td></tr><tr><td>2011</td><td>227788137</td></tr><tr><td>2012</td><td>428839698</td></tr><tr><td>2013</td><td>3469434877</td></tr><tr><td>2014</td><td>850978369</td></tr><tr><td>2015</td><td>201655376</td></tr><tr><td>2016</td><td>540582363</td></tr><tr><td>2017</td><td>254767487</td></tr><tr><td>2018</td><td>1529849832</td></tr><tr><td>2019</td><td>3829900850</td></tr><tr><td>2020</td><td>1251422083</td></tr><tr><td>2021</td><td>61396266</td></tr><tr><td>2022</td><td>9958922</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>breach_method</th><th>total_records</th></tr></thead><tbody><tr><td>Hacked</td><td>97409783853</td></tr><tr><td>Poor Security</td><td>3811143378</td></tr><tr><td>Unknown</td><td>448253141</td></tr><tr><td>Poor Security / Hacked</td><td>412214295</td></tr><tr><td>Accidentally Published</td><td>269917505</td></tr><tr><td>Data Exposed By Misconfiguration</td><td>250000000</td></tr><tr><td>Lost / Stolen Media</td><td>170434561</td></tr><tr><td>Unsecured S3 Bucket</td><td>106000000</td></tr><tr><td>Misconfiguration/poor Security</td><td>100000000</td></tr><tr><td>Unprotected Api</td><td>100000000</td></tr><tr><td>Inside Job, Hacked</td><td>92000000</td></tr><tr><td>Inside Job</td><td>76426105</td></tr><tr><td>Lost / Stolen Computer</td><td>41397666</td></tr><tr><td>Publicly Accessible Amazon Web Services (aws) Server</td><td>38000000</td></tr><tr><td>Improper Setting, Hacked</td><td>21457751</td></tr><tr><td>Social Engineering</td><td>6054459</td></tr><tr><td>Poor Security/inside Job</td><td>5214200</td></tr><tr><td>Ransomware Hacked</td><td>1648922</td></tr><tr><td>Accidentally Uploaded</td><td>1500000</td></tr><tr><td>Intentionally Lost</td><td>960000</td></tr><tr><td>Accidentally Exposed</td><td>900000</td></tr><tr><td>Rogue Contractor</td><td>30000</td></tr><tr><td>Zero-day Vulnerabilities</td><td>null</td></tr><tr><td>Hacked/misconfiguration</td><td>null</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) AS total_nulls
FROM main.gold.fact_cyber_breaches
WHERE records_exposed IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_nulls</th></tr></thead><tbody><tr><td>30</td></tr></tbody></table></div>

-- %%
--- Tratativas

ALTER TABLE main.gold.fact_cyber_breaches
ADD CONSTRAINT chk_records_exposed_positive
CHECK (records_exposed >= 0 OR records_exposed IS NULL);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
---Garantindo que as abelas não estão vazias

SELECT 'fact' AS tabela, COUNT(*) AS total FROM main.gold.fact_cyber_breaches
UNION ALL
SELECT 'dim_organization', COUNT(*) FROM main.gold.dim_organization
UNION ALL
SELECT 'dim_organization_type', COUNT(*) FROM main.gold.dim_organization_type
UNION ALL
SELECT 'dim_breach_method', COUNT(*) FROM main.gold.dim_breach_method
UNION ALL
SELECT 'dim_year', COUNT(*) FROM main.gold.dim_year;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tabela</th><th>total</th></tr></thead><tbody><tr><td>fact</td><td>352</td></tr><tr><td>dim_organization</td><td>331</td></tr><tr><td>dim_organization_type</td><td>70</td></tr><tr><td>dim_breach_method</td><td>25</td></tr><tr><td>dim_year</td><td>20</td></tr></tbody></table></div>

-- %%
---Consulta FKs não nulas

SELECT
  SUM(CASE WHEN organization_key IS NULL THEN 1 ELSE 0 END) AS org_null,
  SUM(CASE WHEN organization_type_key IS NULL THEN 1 ELSE 0 END) AS type_null,
  SUM(CASE WHEN breach_method_key IS NULL THEN 1 ELSE 0 END) AS method_null,
  SUM(CASE WHEN year_key IS NULL THEN 1 ELSE 0 END) AS year_null
FROM main.gold.fact_cyber_breaches;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>org_null</th><th>type_null</th><th>method_null</th><th>year_null</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) AS fk_orfa
FROM main.gold.fact_cyber_breaches f
LEFT JOIN main.gold.dim_year d
  ON f.year_key = d.year_key
WHERE d.year_key IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fk_orfa</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
--- Teste de consulta analítica

SELECT
  y.year,
  bm.breach_method,
  SUM(f.records_exposed) AS total_records
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y ON f.year_key = y.year_key
JOIN main.gold.dim_breach_method bm ON f.breach_method_key = bm.breach_method_key
GROUP BY y.year, bm.breach_method
ORDER BY y.year;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>breach_method</th><th>total_records</th></tr></thead><tbody><tr><td>-1</td><td>Hacked</td><td>90002365208</td></tr><tr><td>2004</td><td>Inside Job, Hacked</td><td>92000000</td></tr><tr><td>2004</td><td>Inside Job</td><td>510000</td></tr><tr><td>2005</td><td>Hacked</td><td>41400000</td></tr><tr><td>2005</td><td>Lost / Stolen Media</td><td>5300000</td></tr><tr><td>2005</td><td>Poor Security</td><td>125000</td></tr><tr><td>2006</td><td>Accidentally Published</td><td>20000000</td></tr><tr><td>2006</td><td>Intentionally Lost</td><td>960000</td></tr><tr><td>2006</td><td>Lost / Stolen Media</td><td>17200000</td></tr><tr><td>2006</td><td>Hacked</td><td>4000000</td></tr><tr><td>2006</td><td>Inside Job</td><td>2600000</td></tr><tr><td>2006</td><td>Lost / Stolen Computer</td><td>26500000</td></tr><tr><td>2007</td><td>Hacked</td><td>106100000</td></tr><tr><td>2007</td><td>Inside Job</td><td>18226405</td></tr><tr><td>2007</td><td>Lost / Stolen Media</td><td>28160000</td></tr><tr><td>2007</td><td>Lost / Stolen Computer</td><td>800000</td></tr><tr><td>2008</td><td>Lost / Stolen Media</td><td>16534500</td></tr><tr><td>2008</td><td>Lost / Stolen Computer</td><td>2382000</td></tr><tr><td>2008</td><td>Hacked</td><td>27500000</td></tr><tr><td>2008</td><td>Accidentally Published</td><td>11550000</td></tr><tr><td>2008</td><td>Inside Job</td><td>11100000</td></tr><tr><td>2009</td><td>Hacked</td><td>176521778</td></tr><tr><td>2009</td><td>Lost / Stolen Media</td><td>77595209</td></
JOIN main.gold.dim_breach_method bm
  ON f.breach_method_key = bm.breach_method_key
GROUP BY bm.breach_method
ORDER BY total_incidentes DESC;


--Frequência absoluta de cada método de ataque
--Identifica os vetores mais recorrentes
--Base para priorização de controles de segurança

-- Interpretação esperada

--Ataques como Hacking, Misconfiguration, Accidentally Published e Insider tendem a aparecer com maior frequência, indicando falhas técnicas e humanas como principais vetores.
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>breach_method</th><th>total_incidentes</th></tr></thead><tbody><tr><td>Hacked</td><td>192</td></tr><tr><td>Poor Security</td><td>44</td></tr><tr><td>Lost / Stolen Media</td><td>33</td></tr><tr><td>Accidentally Published</td><td>21</td></tr><tr><td>Inside Job</td><td>19</td></tr><tr><td>Lost / Stolen Computer</td><td>16</td></tr><tr><td>Unknown</td><td>8</td></tr><tr><td>Improper Setting, Hacked</td><td>2</td></tr><tr><td>Poor Security/inside Job</td><td>2</td></tr><tr><td>Inside Job, Hacked</td><td>1</td></tr><tr><td>Misconfiguration/poor Security</td><td>1</td></tr><tr><td>Data Exposed By Misconfiguration</td><td>1</td></tr><tr><td>Publicly Accessible Amazon Web Services (aws) Server</td><td>1</td></tr><tr><td>Accidentally Uploaded</td><td>1</td></tr><tr><td>Accidentally Exposed</td><td>1</td></tr><tr><td>Zero-day Vulnerabilities</td><td>1</td></tr><tr><td>Unprotected Api</td><td>1</td></tr><tr><td>Poor Security / Hacked</td><td>1</td></tr><tr><td>Ransomware Hacked</td><td>1</td></tr><tr><td>Unsecured S3 Bucket</td><td>1</td></tr><tr><td>Intentionally Lost</td><td>1</td></tr><tr><td>Rogue Contractor</td><td>1</td></tr><tr><td>Social Engineering</td><td>1</td></tr><tr><td>Hacked/misconfiguration</td><td>1</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
--2.	Por que os ataques às empresas estão aumentando?

SELECT
  y.year,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y
  ON f.year_key = y.year_key
WHERE y.year <> -1
GROUP BY y.year
ORDER BY y.year;

--Esta é uma pergunta interpretativa, não é totalmente estatística.

-- O aumento pode ser associado a:

-- maior volume de dados sensíveis armazenados
-- maior exposição pública
-- maior interesse dos atacantes
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>total_incidentes</th></tr></thead><tbody><tr><td>2004</td><td>2</td></tr><tr><td>2005</td><td>6</td></tr><tr><td>2006</td><td>7</td></tr><tr><td>2007</td><td>12</td></tr><tr><td>2008</td><td>16</td></tr><tr><td>2009</td><td>13</td></tr><tr><td>2010</td><td>19</td></tr><tr><td>2011</td><td>34</td></tr><tr><td>2012</td><td>23</td></tr><tr><td>2013</td><td>28</td></tr><tr><td>2014</td><td>25</td></tr><tr><td>2015</td><td>28</td></tr><tr><td>2016</td><td>22</td></tr><tr><td>2017</td><td>9</td></tr><tr><td>2018</td><td>26</td></tr><tr><td>2019</td><td>30</td></tr><tr><td>2020</td><td>31</td></tr><tr><td>2021</td><td>13</td></tr><tr><td>2022</td><td>5</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
--3.	Quais tipos de empresas são mais visadas de ataques?

SELECT
  ot.organization_type,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_organization_type ot
  ON f.organization_type_key = ot.organization_type_key
GROUP BY ot.organization_type
ORDER BY total_incidentes DESC
LIMIT 10;


--Interpretação

--Setores como:

--Government
--Healthcare
--Financial
--Technology
--tendem a concentrar mais incidentes, refletindo:
--valor dos dados
--criticidade dos serviços
--maior visibilidade pública
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>organization_type</th><th>total_incidentes</th></tr></thead><tbody><tr><td>Web</td><td>53</td></tr><tr><td>Healthcare</td><td>47</td></tr><tr><td>Financial</td><td>38</td></tr><tr><td>Government</td><td>30</td></tr><tr><td>Retail</td><td>27</td></tr><tr><td>Tech</td><td>19</td></tr><tr><td>Academic</td><td>13</td></tr><tr><td>Gaming</td><td>12</td></tr><tr><td>Telecoms</td><td>12</td></tr><tr><td>Hotel</td><td>8</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
--4.	Para cada tipo de ataque, qual é a forma mais eficiente de prevenção?

SELECT
  bm.breach_method,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_breach_method bm
  ON f.breach_method_key = bm.breach_method_key
GROUP BY bm.breach_method;

--Associação técnica (exemplo)
--Tipo de ataque	Medida de prevenção
--Hacking	Hardening, MFA, IDS/IPS
--Misconfiguration	IaC, revisão de configs
--Accidentally Published	DLP, controle de acesso
--Insider	IAM, segregação de funções
--Lost / Stolen	Criptografia, MDM
-- Observação acadêmica:
--As medidas não vêm do dataset, mas de boas práticas de cibersegurança.
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>breach_method</th><th>total_incidentes</th></tr></thead><tbody><tr><td>Inside Job, Hacked</td><td>1</td></tr><tr><td>Misconfiguration/poor Security</td><td>1</td></tr><tr><td>Improper Setting, Hacked</td><td>2</td></tr><tr><td>Data Exposed By Misconfiguration</td><td>1</td></tr><tr><td>Unknown</td><td>8</td></tr><tr><td>Publicly Accessible Amazon Web Services (aws) Server</td><td>1</td></tr><tr><td>Hacked</td><td>192</td></tr><tr><td>Accidentally Uploaded</td><td>1</td></tr><tr><td>Accidentally Exposed</td><td>1</td></tr><tr><td>Zero-day Vulnerabilities</td><td>1</td></tr><tr><td>Unprotected Api</td><td>1</td></tr><tr><td>Poor Security / Hacked</td><td>1</td></tr><tr><td>Ransomware Hacked</td><td>1</td></tr><tr><td>Unsecured S3 Bucket</td><td>1</td></tr><tr><td>Inside Job</td><td>19</td></tr><tr><td>Intentionally Lost</td><td>1</td></tr><tr><td>Accidentally Published</td><td>21</td></tr><tr><td>Poor Security/inside Job</td><td>2</td></tr><tr><td>Rogue Contractor</td><td>1</td></tr><tr><td>Poor Security</td><td>44</td></tr><tr><td>Lost / Stolen Media</td><td>33</td></tr><tr><td>Social Engineering</td><td>1</td></tr><tr><td>Lost / Stolen Computer</td><td>16</td></tr><tr><td>Hacked/misconfiguration</td><td>1</td></tr></tbody></table></div>

-- %%
--4.	Para cada tipo de ataque, qual é a forma mais eficiente de prevenção? (COMPLEMENTO)
--Tipo organização X Método de ataque

SELECT
  ot.organization_type,
  bm.breach_method,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_organization_type ot
  ON f.organization_type_key = ot.organization_type_key
JOIN main.gold.dim_breach_method bm
  ON f.breach_method_key = bm.breach_method_key
GROUP BY
  ot.organization_type,
  bm.breach_method
  LIMIT 25;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>organization_type</th><th>breach_method</th><th>total_incidentes</th></tr></thead><tbody><tr><td>Government</td><td>Hacked</td><td>8</td></tr><tr><td>Tech</td><td>Lost / Stolen Computer</td><td>1</td></tr><tr><td>Energy</td><td>Inside Job</td><td>2</td></tr><tr><td>Tech, Web</td><td>Hacked</td><td>1</td></tr><tr><td>Tech, Retail</td><td>Accidentally Published</td><td>1</td></tr><tr><td>Academic</td><td>Hacked</td><td>9</td></tr><tr><td>Hosting Provider</td><td>Hacked</td><td>1</td></tr><tr><td>Military</td><td>Hacked</td><td>1</td></tr><tr><td>Government</td><td>Poor Security</td><td>4</td></tr><tr><td>Social Network</td><td>Poor Security</td><td>5</td></tr><tr><td>Hotel</td><td>Hacked</td><td>7</td></tr><tr><td>Hotel</td><td>Poor Security/inside Job</td><td>1</td></tr><tr><td>Web, Gaming</td><td>Hacked</td><td>1</td></tr><tr><td>Healthcare</td><td>Lost / Stolen Media</td><td>14</td></tr><tr><td>Financial</td><td>Lost / Stolen Media</td><td>7</td></tr><tr><td>Financial</td><td>Inside Job</td><td>6</td></tr><tr><td>Financial Service Company</td><td>Poor Security</td><td>1</td></tr><tr><td>Healthcare</td><td>Unknown</td><td>1</td></tr><tr><td>Restaurant</td><td>Hacked</td><td>3</td></tr><tr><td>Tech</td><td>Data Exposed By Misconfiguration</td><td>1</td></tr><tr><td>Financial</td><td>Intentionally Lost</td><td>1</td></tr><tr><td>Clinical Laboratory</td><td>Poor Security</td><td>1</td></tr><tr><td>Military, Healthcare</td><td>Lost / Stolen Computer</td><td>1</td></tr><tr><td>Telephone Directory</td><td>Unknown</td><td>1</td></tr><tr><td>Military</td><td>Lost / Stolen Media</td><td>2</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
--5.	As análises permitem prever cenários futuros de segurança cibernética? Quais são as perspectivas?


SELECT
  y.year,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y
  ON f.year_key = y.year_key
WHERE y.year <> -1
GROUP BY y.year
ORDER BY y.year;

--conclusão técnica
--O dataset permite identificar tendências históricas
--Não permite previsão determinística
--Pode apoiar análises exploratórias e projeções simples
--Modelos preditivos exigiriam:
--dados contínuos
--mais variáveis
--séries temporais completas
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>total_incidentes</th></tr></thead><tbody><tr><td>2004</td><td>2</td></tr><tr><td>2005</td><td>6</td></tr><tr><td>2006</td><td>7</td></tr><tr><td>2007</td><td>12</td></tr><tr><td>2008</td><td>16</td></tr><tr><td>2009</td><td>13</td></tr><tr><td>2010</td><td>19</td></tr><tr><td>2011</td><td>34</td></tr><tr><td>2012</td><td>23</td></tr><tr><td>2013</td><td>28</td></tr><tr><td>2014</td><td>25</td></tr><tr><td>2015</td><td>28</td></tr><tr><td>2016</td><td>22</td></tr><tr><td>2017</td><td>9</td></tr><tr><td>2018</td><td>26</td></tr><tr><td>2019</td><td>30</td></tr><tr><td>2020</td><td>31</td></tr><tr><td>2021</td><td>13</td></tr><tr><td>2022</td><td>5</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
--Complemento da pergunta 5 - "As análises permitem prever cenários futuros de segurança cibernética? Quais são as perspectivas? " 
---Evolução dos métodos de ataque ao longo do tempo

SELECT
  y.year,
  bm.breach_method,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y
  ON f.year_key = y.year_key
JOIN main.gold.dim_breach_method bm
  ON f.breach_method_key = bm.breach_method_key
WHERE y.year <> -1
GROUP BY y.year, bm.breach_method
ORDER BY y.year, total_incidentes DESC
LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>breach_method</th><th>total_incidentes</th></tr></thead><tbody><tr><td>2004</td><td>Inside Job, Hacked</td><td>1</td></tr><tr><td>2004</td><td>Inside Job</td><td>1</td></tr><tr><td>2005</td><td>Lost / Stolen Media</td><td>3</td></tr><tr><td>2005</td><td>Hacked</td><td>2</td></tr><tr><td>2005</td><td>Poor Security</td><td>1</td></tr><tr><td>2006</td><td>Lost / Stolen Media</td><td>2</td></tr><tr><td>2006</td><td>Intentionally Lost</td><td>1</td></tr><tr><td>2006</td><td>Inside Job</td><td>1</td></tr><tr><td>2006</td><td>Lost / Stolen Computer</td><td>1</td></tr><tr><td>2006</td><td>Accidentally Published</td><td>1</td></tr><tr><td>2006</td><td>Hacked</td><td>1</td></tr><tr><td>2007</td><td>Inside Job</td><td>4</td></tr><tr><td>2007</td><td>Hacked</td><td>4</td></tr><tr><td>2007</td><td>Lost / Stolen Media</td><td>3</td></tr><tr><td>2007</td><td>Lost / Stolen Computer</td><td>1</td></tr><tr><td>2008</td><td>Lost / Stolen Media</td><td>5</td></tr><tr><td>2008</td><td>Lost / Stolen Computer</td><td>4</td></tr><tr><td>2008</td><td>Accidentally Published</td><td>3</td></tr><tr><td>2008</td><td>Hacked</td><td>3</td></tr><tr><td>2008</td><td>Inside Job</td><td>1</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT
  y.year,
  COUNT(*) AS total_incidentes
FROM main.gold.fact_cyber_breaches f
JOIN main.gold.dim_year y
  ON f.year_key = y.year_key
WHERE y.year >= 2018
GROUP BY y.year
ORDER BY y.year;


---teste simples
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>total_incidentes</th></tr></thead><tbody><tr><td>2018</td><td>26</td></tr><tr><td>2019</td><td>30</td></tr><tr><td>2020</td><td>31</td></tr><tr><td>2021</td><td>13</td></tr><tr><td>2022</td><td>5</td></tr></tbody></table></div>
